# %% [markdown]
# # Data Analytics for Dublin Rental Scenario

# %% [markdown]
# ###  Part 1: Scraping the data from the website
# Upon screening the website(also HTML), it was found that the data has been nested within various sublinks i.e. 2024-Q1, 2024-Q2 etc. Each one of those have 26 more pages containing the rental data. There are majorly two ways of scraping data from paginated webpages - first being by appending query to the index URLs and second is by using different tags in the HTML content of the webpage.
#
# Here, we are trying to scrape the data using the tags from the HTML data of the website.
#
# ##### Approach:
# > Scrape the hyperlinks from the parent website
#
# > Scrape pagination links from those hyperlinks to create one single list
#
# > Scrape all the information from the list of all pages using their HTML tags
#
# > Save the scraped data in a CSV file

# %%
# Defining function which takes single string argument
def rentalScraper (url:str):
    
    # Importing requisite libraries
    import bs4                       # library for webscraping web data
    import urllib                    # library for making HTTP requests
    import csv                       # library for accessing CSV reading/writing capabilities

    
    # Fetching webpage's HTML content
    response = urllib.request.urlopen(url)                    # fetches the HTML content of the page
    html_data = response.read().decode()                      # reads and decodes the HTML content
    soup = bs4.BeautifulSoup(html_data, "html.parser")        # creating an BeautifulSoup object of the parsed HTML content

    
    # Extracting the hyperlink elements (Q1-2024, Q2-2024 etc.)
    hyperlinks_html = soup.find_all("a", href=True)           

    
    # Lists to store extracted links
    hyperlinks = []                                            # lists for Q1-2024, Q2-2024 etc.      
    pagelinks = []                                             # lists for all the pages within the hyperlinks collected

    
    # Base URL for constructing complete page URLs
    indexlink = "http://mlg.ucd.ie/modules/python/assignment1/rental/" 

    
    # Extracting and constructing complete URLs for quarterly rental data.
    for match in hyperlinks_html:
        quarter_links = match.get('href')
        hyperlinks.append(indexlink+quarter_links)            # Concatenating indexlink and the extracted quarter_links to create a complete URL
        '''print(quarter_links)'''                            # (Commented out) Used to check extracted links

        
    # Extracting and constructing complete URLs from all the pages of quarterly rental data
    for links in (hyperlinks[1:]):                                # Skipping the first as it leads to homepage of the website
        response = urllib.request.urlopen(links)                  # fetches the HTML content of the page
        html_data = response.read().decode()                      # reads and decodes the HTML content
        soup = bs4.BeautifulSoup(html_data, "html.parser")        # creating an BeautifulSoup object of the parsed HTML content

        
        # Finding all the paginated links on the page
        pagelinks_html = soup.find_all("a", href=True)            # finding all the <a> tags containing "href" attributes
        pagelinks.append(links)                                   # storing the first page of quarterly data    
        for match in pagelinks_html[1:(len(pagelinks_html)-1)]:   # storing the remaining pages excluding the "Next" pagelink
            pages = match['href']                                 
            pagelinks.append(indexlink + pages)                   # Concatenating indexlink and the extracted quarter_links to create a complete URL
            
    '''for i in pagelinks:                                        # (Commented out) Used to check extracted links
        print(i)'''

    
    # Lists to store extracted rental details
    price       = []
    month       = []
    prop_type   = []
    location    = []
    bedrooms    = []
    bathrooms   = []
    parking     = []
    garden      = []
    lease       = []
    contact     = [] 
    rental_info = []

    
    # Scraping rental details from each pagination link
    for links in pagelinks:
        response = urllib.request.urlopen(links)                               # fetches the HTML content of the page
        pagelink_html_data = response.read().decode()                          # reads and decodes the HTML content
        soup = bs4.BeautifulSoup(pagelink_html_data, "html.parser")            # creating an BeautifulSoup object of the parsed HTML content

        
        # Finding all <li> elements (list items) on the page
        tag_li = soup.find_all("li")
        for li in tag_li:
            month.append(soup.find("span", {"class":"record"}).text.strip())    # Extract and store the rental record month

            
            # Each rental property record is represented within a table, and the details are stored within <tr> tags.
            # Each <tr> tag contains multiple <td> tags, with the property details listed sequentially across rows
            # Since there are a total of 9 fields we will iterate it 9 times over a list i.e. in range (0,8)
            tag_tr = li.find_all("tr")
            for i in range (0,8):                                               
                if (i==0):
                    price.append((tag_tr[i].find_all("td")[1]).text.strip())
                elif (i==1):
                    prop_type.append((tag_tr[i].find_all("td")[1]).text.strip())
                elif (i==2):
                    location.append((tag_tr[i].find_all("td")[1]).text.strip())
                elif (i==3):
                    bedrooms.append((tag_tr[i].find_all("td")[1]).text.strip())
                elif (i==4):
                    bathrooms.append((tag_tr[i].find_all("td")[1]).text.strip())
                elif (i==5):
                    parking.append((tag_tr[i].find_all("td")[1]).text.strip())
                elif (i==6):
                    garden.append((tag_tr[i].find_all("td")[1]).text.strip())
                elif (i==7):
                    lease.append((tag_tr[i].find_all("td")[1]).text.strip())
                    
            contact.append((tag_tr[8].find_all("td")[1]).text.strip())

            
    # Storing the extracted data into a dictionary which will be used to create the CSV using DictWriter class of CSV module
    for i in range(len(month)):
        temp_dict = {"Month":month[i], 
                     "Price":price[i], 
                     "Property Type":prop_type[i], 
                     "Location":location[i], 
                     "Bedrooms":bedrooms[i], 
                     "Bathrooms":bathrooms[i], 
                     "Parking":parking[i], 
                     "Garden":garden[i], 
                     "Lease Length":lease[i], 
                     "Contact":contact[i]}
        
        rental_info.append(temp_dict)
        

    # Writing the data into a CSV file for further analysis
    with open ("DublinRental.csv", "w", encoding="utf-8") as file:
        fields = ["Month", "Price",                         # defining fields
                  "Property Type", 
                  "Location", 
                  "Bedrooms", 
                  "Bathrooms", 
                  "Parking", 
                  "Garden", 
                  "Lease Length", 
                  "Contact"]
        writer = csv.DictWriter(file, fieldnames=fields)    # creating a CSV writer object
        writer.writeheader()                                # writing the header row 
        for property in rental_info:                        # writing each rental record to CSV as a row
            writer.writerow(property)
    return (print(f"Process complete. \n{len(price)} rental records have been added to the CSV file 'DublinRental.csv'."))

# %% [markdown]
# ### Running the function

# %%
rentalScraper("http://mlg.ucd.ie/modules/python/assignment1/rental/index.html")
# Out:
# Process complete.
# 1950 rental records have been added to the CSV file 'DublinRental.csv'.

# %% [markdown]
# ### Verifying the output file

# %%
with open ("DublinRental.csv", "r") as file:
    reader = csv.DictReader(file)
    for property in reader:
        print (f"{property}\n")
# Out:
# {'Month': 'January 2024', 'Price': '€ 7,200', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '3', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,960 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 24', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': '???', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€1,920.00 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 24', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,590', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 4,360 per month', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '3', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 4,000 per month', 'Property Type': 'House', 'Location': 'North Co Dublin', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€4,530.00', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 17', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '3 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,440 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 8', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,940', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,290', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 4,440', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 16', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '3 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,500 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 990 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6W', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 4,090', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,190', 'Property Type': 'Apartment', 'Location': 'South Co Dublin', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,500', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,910', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 930', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 5,550', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,230', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 9', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,060', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,150', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 3', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 4,410', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Y', 'Garden': 'Yes', 'Lease Length': '3 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,600', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 24', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,390 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 11', 'Bedrooms': '1', 'Bathrooms': '2 Bathrooms', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,000', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 13', 'Bedrooms': '2', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'N', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,080', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 15', 'Bedrooms': '1', 'Bathrooms': '1', 'Parking': '???', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,510', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': '???', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,420', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 18', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': '???', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,500', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 13', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€3,200.00', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,730', 'Property Type': 'Apartment', 'Location': 'South Co Dublin', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,340', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 15', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,320', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,060', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 14', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,760', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 24', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,500 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 3', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '3.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€2,400.00', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 6W', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '3 Bathrooms', 'Parking': '???', 'Garden': 'Y', 'Lease Length': '6 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€3,890.00', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 10', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,120', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 14', 'Bedrooms': '2', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 4,720', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 7', 'Bedrooms': '2', 'Bathrooms': '2 Bathrooms', 'Parking': '???', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,510', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 18', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,930', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 14', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '6.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,790', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 20', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': '???', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,040', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 15', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '2', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '???', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,060', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 3', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,140', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6.0', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,680', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 15', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,920', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 15', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1', 'Parking': '???', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,510', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 24', 'Bedrooms': '1', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,830', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,140', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 4,090', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '3', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,700 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,430', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,550 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 4,550 per month', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 22', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '3 Bathrooms', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,860', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,220', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'N', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,160 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 13', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,530', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 18', 'Bedrooms': '2', 'Bathrooms': '2 Bathrooms', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,130', 'Property Type': 'Apartment', 'Location': 'North Co Dublin', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 3,430', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 12', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,980', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,450', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 7', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,900', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'N', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 780 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 10', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2', 'Parking': 'No', 'Garden': '???', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,190', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'N', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,030', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 8', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'N', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,000', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,590', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 24', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€1,250.00', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 11', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,860', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 5', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,320', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 4,490', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 13', 'Bedrooms': '3', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,060', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,700', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 7', 'Bedrooms': '4', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 5,580', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,920', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2', 'Bathrooms': '1', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,570 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'N', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 3,320', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,050', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 5', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€4,320.00', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 9', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '12.0', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€1,800.00', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,180', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,300', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 12', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,070', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 11', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,510', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2', 'Parking': '???', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 930', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 12', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,980', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,120', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 3,680 per month', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 17', 'Bedrooms': '3', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,390 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1', 'Bathrooms': '2', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,510', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 18', 'Bedrooms': '1', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': '???', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 4,910 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 5,470', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,450', 'Property Type': 'Apartment', 'Location': 'South Co Dublin', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,470', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 4,190', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,750', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,620', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,460', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 12', 'Bedrooms': '2', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,900 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,320', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 5,220', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,240', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,010 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 6,030', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': '???', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,830', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 20', 'Bedrooms': '3', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '3.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 5,340 per month', 'Property Type': 'House', 'Location': 'North Co Dublin', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '3 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 3,820', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '3.0', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,600 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,880', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 17', 'Bedrooms': '3', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '6.0', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,800', 'Property Type': 'Apartment', 'Location': 'South Co Dublin', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,990', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€1,130.00 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 8', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,280', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,240 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,260 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1', 'Bathrooms': '2', 'Parking': 'Y', 'Garden': 'No', 'Lease Length': '3.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 5,450', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 5', 'Bedrooms': '5 Bedrooms', 'Bathrooms': '4 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '6.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 800', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 24', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 890', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 12', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 4,460', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 8', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'N', 'Garden': 'Yes', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,530', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 9', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,520', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,620', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 8', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Y', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,850', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,970', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 940', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,720', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 15', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '4 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '3 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€1,730.00', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,980', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,760', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'N', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,350', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 17', 'Bedrooms': '3', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€1,230.00', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 4,000', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 15', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€2,960.00 per month', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 24', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,160', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 9', 'Bedrooms': '1', 'Bathrooms': '2', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,990 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 9', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€1,220.00 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 20', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 4,490', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 3', 'Bedrooms': '3', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '6 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,590 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 4,530', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 670', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 22', 'Bedrooms': '1', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,180 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 3', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'N', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,210', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 10', 'Bedrooms': '1', 'Bathrooms': '1', 'Parking': 'Yes', 'Garden': '???', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 6,320', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '3', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': '???', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,860', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,910', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 10', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,400', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 8', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1', 'Parking': '???', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,210', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,520', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,750', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 16', 'Bedrooms': '3', 'Bathrooms': '2 Bathrooms', 'Parking': '???', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€1,270.00 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': '???', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 5,890', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 5', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '3 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 5,220 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 9', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': '???', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 5,010', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 8', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2', 'Parking': 'Y', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,540', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 24', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,590 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '???', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,100', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,110', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 11', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,680', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 18', 'Bedrooms': '3', 'Bathrooms': '1 Bathroom', 'Parking': 'Y', 'Garden': 'No', 'Lease Length': '6.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 940', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€4,450.00', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 10', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 5,190', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'N', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,110', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 3,320', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 7', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '3 Bathrooms', 'Parking': 'Y', 'Garden': 'Y', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,010', 'Property Type': 'Apartment', 'Location': 'South Co Dublin', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'N', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 2,270', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,390 per month', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 6W', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Y', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,000', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 3,620 per month', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '3', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,200', 'Property Type': 'Apartment', 'Location': 'South Co Dublin', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€2,140.00', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 20', 'Bedrooms': '3', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,130', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 22', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 2,520', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 9', 'Bedrooms': '2', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,070', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'January 2024', 'Price': '€ 1,370', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': '???', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,880 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'January 2024', 'Price': '€ 1,410', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'February 2024', 'Price': '€ 920', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 17', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'February 2024', 'Price': '€ 7,490 per month', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '3.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'February 2024', 'Price': '€ 2,420', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'February 2024', 'Price': '€ 3,010', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 8', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'February 2024', 'Price': '€ 4,870', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '4 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'February 2024', 'Price': '€ 1,600', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Owner'}
#
# ...
#
# {'Month': 'December 2024', 'Price': '€ 2,850', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 13', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 4,310', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 17', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 3,210', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,630', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 9', 'Bedrooms': '1', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€2,740.00', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '1', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 2,630', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 10', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 3,020 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 3,900', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 3,000 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 2,160', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'N', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€2,110.00', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '2', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 2,200', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,840', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 24', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 2,150', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 20', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,380', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2', 'Bathrooms': '1', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 2,010', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6W', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 2,230', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 2,190', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 6W', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 2,550 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 810', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 17', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'Y', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 1,550', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 16', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,960', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': '???', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 2,260', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 10', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 3,530', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 6', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2', 'Parking': 'Yes', 'Garden': 'Y', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 3,100 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 5', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2', 'Parking': 'N', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,430', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 4,840', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 2,040', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 17', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,070', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 3', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 5,480 per month', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 7', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 2,280 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 3,470', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 8', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 3,830 per month', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 10', 'Bedrooms': '4 Bedrooms', 'Bathrooms': '3 Bathrooms', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 2,270 per month', 'Property Type': 'Apartment', 'Location': 'North Co Dublin', 'Bedrooms': '2', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€1,370.00', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 2,300 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 3,180 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 5,120 per month', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 13', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '6 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 960', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,590', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 5', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,400 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,650', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 4,570', 'Property Type': 'House', 'Location': 'Dublin City South - Dublin 16', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'Yes', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€1,030.00', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 3', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 1,170', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 2,430', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': '???', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,680', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 20', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€1,520.00', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 16', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 1,980', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2', 'Bathrooms': '2 Bathrooms', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,120', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 14', 'Bedrooms': '1 Bedroom', 'Bathrooms': '1', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,240', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 3', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 880', 'Property Type': 'Apartment', 'Location': 'South Co Dublin', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,960', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 22', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€1,740.00', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 2', 'Bedrooms': '2 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 5,750', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 5', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'Yes', 'Garden': 'Yes', 'Lease Length': '3 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 1,880', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '1', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€2,670.00', 'Property Type': 'Apartment', 'Location': 'Dublin City South - Dublin 4', 'Bedrooms': '1 Bedroom', 'Bathrooms': '2', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '6 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 3,050', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 11', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': 'N', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Owner'}
#
# {'Month': 'December 2024', 'Price': '€ 2,060 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 1', 'Bedrooms': '2', 'Bathrooms': '1 Bathroom', 'Parking': 'No', 'Garden': 'No', 'Lease Length': '12 months', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 4,530 per month', 'Property Type': 'Apartment', 'Location': 'Dublin City North - Dublin 9', 'Bedrooms': '3 Bedrooms', 'Bathrooms': '1 Bathroom', 'Parking': '???', 'Garden': 'No', 'Lease Length': '12.0', 'Contact': 'Estate Agent'}
#
# {'Month': 'December 2024', 'Price': '€ 6,700', 'Property Type': 'House', 'Location': 'Dublin City North - Dublin 7', 'Bedrooms': '3', 'Bathrooms': '2 Bathrooms', 'Parking': 'Yes', 'Garden': '???', 'Lease Length': '3 months', 'Contact': 'Owner'}
